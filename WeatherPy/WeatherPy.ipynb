# %%
# %load_ext lab_black

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("../Data/Weather_data.csv")
df.head()
# Out:
#          City Country    Lat    Long   Temp  Feel Like  Wind Speed  Humidity  \
# 0  Hambantota      LK   6.12   81.12  86.00      89.56       16.11        79
# 1     Shimoda      JP  34.67  138.95  68.14      59.52       18.34        64
# 2   Makubetsu      JP  45.37  141.82  68.00      58.42       21.92        72
# 3      Kikwit      CD  -5.04   18.82  71.24      77.83        1.34        94
# 4  Koutsouras      GR  35.03   25.95  75.00      82.83        1.99        92
#
#    Cloud %
# 0       40
# 1       75
# 2       75
# 3      100
# 4        2

# %%
# rechecking unique-ness and length
df["City"].value_counts()
# Out:
# Bonga        1
# Tamandaré    1
# Beloha       1
# Udachny      1
# Dwārka       1
#             ..
# Lüderitz     1
# Karoi        1
# Isangel      1
# Santander    1
# Mahébourg    1
# Name: City, Length: 687, dtype: int64

# %%
# Temperature (F) vs. Latitude
x = df["Lat"]
y = df["Temp"]
plt.figure(figsize=(8, 6))
plt.scatter(x, y)
plt.title("Temperature (F) vs. Latitude")
plt.xlabel("Lat")
plt.ylabel("Temp (F)")
plt.grid()
plt.xlim([-80, 90])
plt.savefig("Scatter_plots/Temperature (F) vs. Latitude.png", facecolor="w")
plt.show()

# %%
# Humidity (%) vs. Latitude
x = df["Lat"]
y = df["Humidity"]
plt.figure(figsize=(8, 6))
plt.scatter(x, y)
plt.title("Humidity (%) vs. Latitude")
plt.xlabel("Lat")
plt.ylabel("Humidity (%)")
plt.grid()
plt.xlim([-80, 90])
plt.savefig("Scatter_plots/Humidity (%) vs. Latitude.png", facecolor="w")
plt.show()

# %%
# Cloudiness (%) vs. Latitude
x = df["Lat"]
y = df["Cloud %"]
plt.figure(figsize=(8, 6))
plt.scatter(x, y)
plt.title("Cloudiness (%) vs. Latitude")
plt.xlabel("Lat")
plt.ylabel("Cloud Cover (%)")
plt.grid()
plt.xlim([-80, 90])
plt.savefig("Scatter_plots/Cloudiness (%) vs. Latitude.png", facecolor="w")
plt.show()

# %%
# Wind Speed (mph) vs. Latitude
x = df["Lat"]
y = df["Wind Speed"]
plt.figure(figsize=(8, 6))
plt.scatter(x, y)
plt.title("Wind Speed (mph) vs. Latitude")
plt.xlabel("Lat")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.xlim([-80, 90])
plt.savefig("Scatter_plots/Wind Speed (mph) vs. Latitude.png", facecolor="w")
plt.show()

# %%
# Northern Hemisphere - Temperature (F) vs. Latitude
X = df.loc[df["Lat"] >= 0]["Lat"].to_frame().values
y = df.loc[df["Lat"] >= 0]["Temp"]

model = LinearRegression()
model.fit(X, y)
intercept = model.intercept_
slope = model.coef_[0]
r2 = model.score(X, y)
predict = model.predict(X)
formula = "Y = " + str(round(slope, 2)) + " x + " + str(round(intercept, 2))
r2_str = f"$R^{2}$ = {round(r2, 4)}"

plt.figure(figsize=(8, 6))
plt.scatter(X, y)
plt.plot(X, predict, color="r")
plt.title("Northern Hemisphere - Temperature (F) vs. Latitude")
plt.xlabel("Lat")
plt.ylabel("Temp (F)")
plt.annotate(
    formula, (10, 30), color="red", fontsize=15,
)
plt.annotate(
    r2_str, (10, 22), color="red", fontsize=15,
)
plt.grid(10)
plt.xticks(np.arange(0, 81, step=10))
plt.yticks(np.arange(0, 101, step=10))
plt.xlim([-1, 81])
plt.savefig(
    "Scatter_plots/Northern Hemisphere - Temperature (F) vs. Latitude.png",
    facecolor="w",
)
plt.show()

# %%
# Southern Hemisphere - Temperature (F) vs. Latitude
X = df.loc[df["Lat"] <= 0]["Lat"].to_frame().values
y = df.loc[df["Lat"] <= 0]["Temp"]

model = LinearRegression()
model.fit(X, y)
intercept = model.intercept_
slope = model.coef_[0]
r2 = model.score(X, y)
predict = model.predict(X)
formula = "Y = " + str(round(slope, 2)) + " x + " + str(round(intercept, 2))
r2_str = f"$R^{2}$ = {round(r2, 4)}"

plt.figure(figsize=(8, 6))
plt.scatter(X, y)
plt.plot(X, predict, color="r")
plt.title("Southern Hemisphere - Temperature (F) vs. Latitude")
plt.xlabel("Lat")
plt.ylabel("Temp (F)")
plt.annotate(
    formula, (-20, 45), color="red", fontsize=15,
)
plt.annotate(
    r2_str, (-20, 39), color="red", fontsize=15,
)
plt.grid()
# plt.xticks(np.arange(0, -81, step=10))
# plt.yticks(np.arange(0, 81, step=10))
plt.xlim([-60, 1])
plt.savefig(
    "Scatter_plots/Southern Hemisphere - Temperature (F) vs. Latitude.png",
    facecolor="w",
)
plt.show()

# %%
# Northern Hemisphere - Humidity (%) vs. Latitude
X = df.loc[df["Lat"] >= 0]["Lat"].to_frame().values
y = df.loc[df["Lat"] >= 0]["Humidity"]

model = LinearRegression()
model.fit(X, y)
intercept = model.intercept_
slope = model.coef_[0]
r2 = model.score(X, y)
predict = model.predict(X)
formula = "Y = " + str(round(slope, 2)) + " x + " + str(round(intercept, 2))
r2_str = f"$R^{2}$ = {round(r2, 4)}"

plt.figure(figsize=(8, 6))
plt.scatter(X, y)
plt.plot(X, predict, color="r")
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude")
plt.xlabel("Lat")
plt.ylabel("Humidity (%)")
plt.annotate(
    formula, (10, 30), color="red", fontsize=15,
)
plt.annotate(
    r2_str, (10, 22), color="red", fontsize=15,
)
plt.grid(10)
plt.xticks(np.arange(0, 81, step=10))
plt.yticks(np.arange(0, 101, step=10))
plt.xlim([-1, 81])
plt.savefig(
    "Scatter_plots/Northern Hemisphere - Humidity (%) vs. Latitude.png", facecolor="w",
)
plt.show()

# %%
# Southern Hemisphere - Humidity (%) vs. Latitude
X = df.loc[df["Lat"] <= 0]["Lat"].to_frame().values
y = df.loc[df["Lat"] <= 0]["Humidity"]

model = LinearRegression()
model.fit(X, y)
intercept = model.intercept_
slope = model.coef_[0]
r2 = model.score(X, y)
predict = model.predict(X)
formula = "Y = " + str(round(slope, 2)) + " x + " + str(round(intercept, 2))
r2_str = f"$R^{2}$ = {round(r2, 4)}"

plt.figure(figsize=(8, 6))
plt.scatter(X, y)
plt.plot(X, predict, color="r")
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude")
plt.xlabel("Lat")
plt.ylabel("Humidity (%)")
plt.annotate(
    formula, (-55, 30), color="red", fontsize=15,
)
plt.annotate(
    r2_str, (-55, 25), color="red", fontsize=15,
)
plt.grid()
# plt.xticks(np.arange(0, -81, step=10))
# plt.yticks(np.arange(0, 81, step=10))
plt.xlim([-60, 1])
plt.savefig(
    "Scatter_plots/Southern Hemisphere - Humidity (%) vs. Latitude.png", facecolor="w",
)
plt.show()

# %%
# Northern Hemisphere - Cloudiness (%) vs. Latitude
X = df.loc[df["Lat"] >= 0]["Lat"].to_frame().values
y = df.loc[df["Lat"] >= 0]["Cloud %"]

model = LinearRegression()
model.fit(X, y)
intercept = model.intercept_
slope = model.coef_[0]
r2 = model.score(X, y)
predict = model.predict(X)
formula = "Y = " + str(round(slope, 2)) + " x + " + str(round(intercept, 2))
r2_str = f"$R^{2}$ = {round(r2, 4)}"

plt.figure(figsize=(8, 6))
plt.scatter(X, y)
plt.plot(X, predict, color="r")
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude")
plt.xlabel("Lat")
plt.ylabel("Cloud Cover (%)")
plt.annotate(
    formula, (-55, 30), color="red", fontsize=15,
)
plt.annotate(
    r2_str, (-55, 25), color="red", fontsize=15,
)
plt.grid()
# plt.xticks(np.arange(0, -81, step=10))
# plt.yticks(np.arange(0, 81, step=10))
plt.xlim([-1, 81])
plt.savefig(
    "Scatter_plots/Northern Hemisphere - Cloudiness (%) vs. Latitude.png",
    facecolor="w",
)
plt.show()

# %%
# Southern Hemisphere - Cloudiness (%) vs. Latitude
X = df.loc[df["Lat"] <= 0]["Lat"].to_frame().values
y = df.loc[df["Lat"] <= 0]["Cloud %"]

model = LinearRegression()
model.fit(X, y)
intercept = model.intercept_
slope = model.coef_[0]
r2 = model.score(X, y)
predict = model.predict(X)
formula = "Y = " + str(round(slope, 2)) + " x + " + str(round(intercept, 2))
r2_str = f"$R^{2}$ = {round(r2, 4)}"

plt.figure(figsize=(8, 6))
plt.scatter(X, y)
plt.plot(X, predict, color="r")
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude")
plt.xlabel("Lat")
plt.ylabel("Cloud Cover (%)")
plt.annotate(
    formula, (-55, 30), color="red", fontsize=15,
)
plt.annotate(
    r2_str, (-55, 25), color="red", fontsize=15,
)
plt.grid()
# plt.xticks(np.arange(0, -81, step=10))
# plt.yticks(np.arange(0, 81, step=10))
plt.xlim([-60, 1])
plt.savefig(
    "Scatter_plots/Southern Hemisphere - Cloudiness (%) vs. Latitude.png",
    facecolor="w",
)
plt.show()

# %%
# Northern Hemisphere - Wind Speed (mph) vs. Latitude
X = df.loc[df["Lat"] >= 0]["Lat"].to_frame().values
y = df.loc[df["Lat"] >= 0]["Wind Speed"]

model = LinearRegression()
model.fit(X, y)
intercept = model.intercept_
slope = model.coef_[0]
r2 = model.score(X, y)
predict = model.predict(X)
formula = "Y = " + str(round(slope, 2)) + " x + " + str(round(intercept, 2))
r2_str = f"$R^{2}$ = {round(r2, 4)}"

plt.figure(figsize=(8, 6))
plt.scatter(X, y)
plt.plot(X, predict, color="r")
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude")
plt.xlabel("Lat")
plt.ylabel("Wind Speed (mph)")
plt.annotate(
    formula, (-55, 30), color="red", fontsize=15,
)
plt.annotate(
    r2_str, (-55, 25), color="red", fontsize=15,
)
plt.grid()
# plt.xticks(np.arange(0, -81, step=10))
# plt.yticks(np.arange(0, 81, step=10))
plt.xlim([-1, 81])
plt.savefig(
    "Scatter_plots/Northern Hemisphere - Wind Speed (mph) vs. Latitude.png",
    facecolor="w",
)
plt.show()

# %%
# Southern Hemisphere - Wind Speed (mph) vs. Latitude
X = df.loc[df["Lat"] <= 0]["Lat"].to_frame().values
y = df.loc[df["Lat"] <= 0]["Wind Speed"]

model = LinearRegression()
model.fit(X, y)
intercept = model.intercept_
slope = model.coef_[0]
r2 = model.score(X, y)
predict = model.predict(X)
formula = "Y = " + str(round(slope, 2)) + " x + " + str(round(intercept, 2))
r2_str = f"$R^{2}$ = {round(r2, 4)}"

plt.figure(figsize=(8, 6))
plt.scatter(X, y)
plt.plot(X, predict, color="r")
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude")
plt.xlabel("Lat")
plt.ylabel("Wind Speed (mph)")
plt.annotate(
    formula, (-55, 30), color="red", fontsize=15,
)
plt.annotate(
    r2_str, (-55, 25), color="red", fontsize=15,
)
plt.grid()
# plt.xticks(np.arange(0, -81, step=10))
# plt.yticks(np.arange(0, 81, step=10))
plt.xlim([-60, 1])
plt.savefig(
    "Scatter_plots/Southern Hemisphere - Wind Speed (mph) vs. Latitude.png",
    facecolor="w",
)
plt.show()
