# %%
# %load_ext lab_black

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../Data/Weather_data.csv")
df.head()
# Out:
#          City Country    Lat    Long   Temp  Feel Like  Wind Speed  Humidity  \
# 0  Hambantota      LK   6.12   81.12  86.00      89.56       16.11        79
# 1     Shimoda      JP  34.67  138.95  68.14      59.52       18.34        64
# 2   Makubetsu      JP  45.37  141.82  68.00      58.42       21.92        72
# 3      Kikwit      CD  -5.04   18.82  71.24      77.83        1.34        94
# 4  Koutsouras      GR  35.03   25.95  75.00      82.83        1.99        92
#
#    Cloud %
# 0       40
# 1       75
# 2       75
# 3      100
# 4        2

# %%
# rechecking unique-ness and length
df["City"].value_counts()
# Out:
# Hambantota       1
# Sittwe           1
# Faya             1
# Okakarara        1
# Kondinskoye      1
#                 ..
# Karaton          1
# Nkoteng          1
# Hasaki           1
# Rio Brilhante    1
# Maniitsoq        1
# Name: City, Length: 687, dtype: int64

# %%
# Temperature (F) vs. Latitude
x = df["Lat"]
y = df["Temp"]
plt.scatter(x, y)
plt.title("Temperature (F) vs. Latitude")
plt.xlabel("Lat")
plt.ylabel("Temp (F)")
plt.grid()
plt.xlim([-80, 90])
plt.savefig("Scatter_plots/Temperature (F) vs. Latitude.png", facecolor="le")
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:10: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   # Remove the CWD from sys.path while we load stuff.

# %%
# Humidity (%) vs. Latitude
x = df["Lat"]
y = df["Humidity"]
plt.figure(figsize=(8, 6))
plt.scatter(x, y)
plt.title("Humidity (%) vs. Latitude")
plt.xlabel("Lat")
plt.ylabel("Humidity (%)")
plt.grid()
plt.xlim([-80, 90])
plt.savefig("Scatter_plots/Humidity (%) vs. Latitude.png")
plt.show()

# %%
# Cloudiness (%) vs. Latitude
x = df["Lat"]
y = df["Cloud %"]

plt.scatter(x, y)
plt.title("Cloudiness (%) vs. Latitude")
plt.xlabel("Lat")
plt.ylabel("Cloud Cover (%)")
plt.grid()
plt.xlim([-80, 90])
plt.savefig("Scatter_plots/Cloudiness (%) vs. Latitude.png")
plt.show()

# %%
# Wind Speed (mph) vs. Latitude
x = df["Lat"]
y = df["Wind Speed"]
plt.figure(figsize=(8, 6))
plt.scatter(x, y)
plt.title("Wind Speed (mph) vs. Latitude")
plt.xlabel("Lat")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.xlim([-80, 90])
plt.savefig("Scatter_plots/Wind Speed (mph) vs. Latitude.png")
plt.show()
